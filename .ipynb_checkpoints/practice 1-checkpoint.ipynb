# %%
print ("hello wordl")
# Out:
# hello wordl

# %%
a =20
print (a)
# Out:
# 20

# %%
b = 20
print(b)
# Out:
# 20

# %%
print(a+b)
# Out:
# 40

# %%
print(a-b)
# Out:
# 0

# %%
print(a/b)
# Out:
# 1.0

# %%
print(a**b)
# Out:
# 104857600000000000000000000

# %%
print(a*b)
# Out:
# 400

# %%
name='Ruksana'
print(name)
# Out:
# Ruksana

# %%
age =2
lastName="khatun"
father= "Riyaj"
print(age, lastName, father)
# Out:
# 2 khatun Riyaj

# %%
print(2+3)
print('HI I AM RUKSANA',23,)
# Out:
# 5
# HI I AM RUIKSANA 23

# %%
A = 2-2+3*4
print(A)
# Out:
# 12

# %%
print(59-90)
# Out:
# -31

# %%
print("Hello python!")
if True :
    print:"True"
else:
   print:"false"
# Out:
# Hello python!

# %%
name = "Ruksana" 
if name=="Ruksana":
     print(name)
else:
   print("false")
# Out:
# Ruksana

# %%
x = 1
y = 35656222554887711
z = -3255522
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print("Hello Ramsha")
print (" i am your best frnd")
# Out:
# Hello Ramsha
#  i am your best frnd

# %%
print("no on knows i am your best frnd except me and you")
# Out:
# no on knows i am your best frnd except me and you

# %%
print("ok that'd good but you know there is one problem i wana to firstofall dedecate one song on you")
# Out:
# ok that'd good but you know there is one problem i wana to firstofall dedecate one song on you

# %%
print(" you konw what one side i am learning c++ and another side i ma learning python but both are i alredy learnd in clg but still some day  i did'nt code any sing of line in python and c++ so i yes i forgot everything so today oneword i will nevre forgot ")
# Out:
#  you konw what one side i am learning c++ and another side i ma learning python but both are i alredy learnd in clg but still some day  i did'nt code any sing of line in python and c++ so i yes i forgot everything so today oneword i will nevre forgot

# %%
lst = list("abc") 
print(list)
# Out:
# <class 'list'>

# %%
a =str ("hello")
print(a)
# Out:
# hello

# %%
A =int(3.4)
print(A)
# Out:
# 3

# %%
b=float(3)
print(b)
# Out:
# 3.0

# %%
a = str(45)
print(a)
# Out:
# 45

# %%
print(f"{'Python':<10}")
# Out:
# Python

# %%
print(f"{'Python':>10}")
# Out:
#     Python

# %%
print(f"{'Python':^10}")
# Out:
#   Python

# %%
(mixed_list )= [1, "Hello", 3.14, True]
print(mixed_list )
# Out:
# [1, 'Hello', 3.14, True]

# %%
x=10
y=10
print(x+y ,x-y, x*y ,x/y ,x//y ,x**y )
# Out:
# 20 0 100 1.0 1 10000000000

# %%
text ="ruksana"
print(text.upper() , text.lower(),text + "WORLD")
# Out:
# RUKSANA ruksana ruksanaWORLD

# %%
name=input('enter your name')
int(name)
print(name)
# Out:
# enter your name 45
# 45

# %%
age = int(input("enter your age"))
if age>=18:
    print(" you are elgibale  to vote")

else:
    print("YOU ARE NOT ELIGIBALE TO VOTE")
# Out:
# enter your age 15
# YOU ARE NOT ELIGIBALE TO VOTE

# %%
for i in range (5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (100):
    print("Ruksana Ai enginner")
# Out:
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner
# Ruksana Ai enginner

# %%
count = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (10):
    if i==4:
     continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 5
# 6
# 7
# 8
# 9

# %%
def greet(name):
    return f"Hello {name}!"

print(greet("Ruksana"))
# Out:
# Hello Ruksana!

# %%
fruits = ["apple", "banana", "mango"]
fruits.append("orange")
print(fruits[1])
# Out:
# banana

# %%
coords = (10, 20)
print(coords[0])
# Out:
# 10

# %%
numbers = {1, 2, 3, 2}  # duplicates removed
print(numbers)
# Out:
# {1, 2, 3}

# %%
person = {"name": "Ruksana", "age": 20}
print(person["name"])
person["age"] = 21
# Out:
# Ruksana

# %%
squares = [x**2 for x in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
double = lambda x: x*2
print(double(5))
# Out:
# 10

# %%
marks=[30, 40,60,90]
print(marks)
# Out:
# [30, 40, 60, 90]

# %%
marks =[]
type(marks)
# Out:
# list

# %%
marks={}
type(marks)
# Out:
# dict

# %%
marks=()
type(marks)
# Out:
# tuple

# %%
student ={"name":"Ruksana", "age":22, "study":"in clg", "passion":"software enginerr"}
print(student)
# Out:
# {'name': 'Ruksana', 'age': 22, 'study': 'in clg', 'passion': 'software enginerr'}

# %%
print("tuple is immutable you can not modifed if you wan to modifes you can not this orderd list")
# Out:
# tuple is immutable you can not modifed if you wan to modifes you can not this orderd list

# %%
t=[2, 3 ,4, 5 ,6, 7]
print(t)
type(t)
len(t)
# Out:
# [2, 3, 4, 5, 6, 7]
# 6

# %%
tuple =(2,3 ,45,67)
print(tuple)
type(tuple)
len(tuple)
# Out:
# (2, 3, 45, 67)
# 4

# %%
set={"apple","banane"}
type(set)
len(set)
# Out:
# 2

# %%
disc ={"studnt":'Ruksana',"age":29}
type(disc) 

len(disc)
disc["studnt"]
disc["age"]
# Out:
# 29

# %%
tuplw=(4,5,6,7,8,3.14,"Ruksana","kHATUN",45)
print(MARKS[5:8])
len(tuplw)
# Out:
# [56]
# 9

# %%
MARKS=[66,88,90,30,65,56]
print(MARKS[1])
print(MARKS[:3])
print(MARKS[5:8])
print(type(MARKS))
# Out:
# 88
# [66, 88, 90]
# [56]
# <class 'list'>

# %%
a = 10
b = 20
sum = a + b
print(f"sum {sum}")
# Out:
# sum 30

# %%
a = 10
b = 20
sum = a + b
print("sum", sum)
# Out:
# sum 30

# %%
print("language is {}".format("language"))
# Out:
# language is language

# %%
print("sum is {}".format(sum))
# Out:
# sum is <built-in function sum>

# %%
a = 10
b = 20
sum = a + b

print("sum is {}".format(sum))
print("sum is {} &{} is {}".format(a ,b,sum))
# Out:
# sum is 30
# sum is 10 &20 is 30

# %%
print("ok i did not undersatnd formating but i just want understand list tuple set dictionary")
# Out:
# ok i did not undersatnd formating but i just want understand list tuple set dictionary

# %%
square=[]
for i in range (6):
    square.append(i*i)

print(square)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
cube=[]
for i in range(9):
    cube.append(i*i*i)
print(cube)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512]

# %%
nums=[3,4,5]
nums.append(40)
nums.append(34)

print(nums)
nums.insert(2,34)
print(nums)
nums.sort()
print(nums)
nums.reverse()
print(nums)
# Out:
# [3, 4, 5, 40, 34]
# [3, 4, 34, 5, 40, 34]
# [3, 4, 5, 34, 34, 40]
# [40, 34, 34, 5, 4, 3]

# %%
for value in nums:
    print(nums)
# Out:
# [40, 34, 34, 5, 4, 3]
# [40, 34, 34, 5, 4, 3]
# [40, 34, 34, 5, 4, 3]
# [40, 34, 34, 5, 4, 3]
# [40, 34, 34, 5, 4, 3]
# [40, 34, 34, 5, 4, 3]
