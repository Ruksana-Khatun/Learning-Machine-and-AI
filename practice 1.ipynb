# %%
print ("hello wordl")
# Out:
# hello wordl

# %%
a =20
print (a)
# Out:
# 20

# %%
b = 20
print(b)
# Out:
# 20

# %%
print(a+b)
# Out:
# 40

# %%
print(a-b)
# Out:
# 0

# %%
print(a/b)
# Out:
# 1.0

# %%
print(a**b)
# Out:
# 104857600000000000000000000

# %%
print(a*b)
# Out:
# 400

# %%
name='Ruksana'
print(name)
# Out:
# Ruksana

# %%
age =2
lastName="khatun"
father= "Riyaj"
print(age, lastName, father)
# Out:
# 2 khatun Riyaj

# %%
print(2+3)
print('HI I AM RUKSANA',23,)
# Out:
# 5
# HI I AM RUIKSANA 23

# %%
A = 2-2+3*4
print(A)
# Out:
# 12

# %%
print(59-90)
# Out:
# -31

# %%
print("Hello python!")
if True :
    print:"True"
else:
   print:"false"
# Out:
# Hello python!

# %%
name = "Ruksana" 
if name=="Ruksana":
     print(name)
else:
   print("false")
# Out:
# Ruksana
